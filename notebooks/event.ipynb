# %% [markdown]
# - play
#     - チームIDごとの，各選手ごとの，各試合での出場，途中出場，ベンチ入り情報
# - score
#     - チームIDごとの，各選手ごとの得点
# - we
#     - チームIDごとの，各選手ごとの警告・退場記録
# - rc
#     - チームIDごとの，各選手ごとの選手登録・抹消記録

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib
import seaborn as sns
import pandas_profiling
from glob import glob

pd.set_option("display.max_columns", None)
# pd.set_option("display.max_rows", 200)

# %%
DATA_DIR = '../input/'

# %%
! ls ../input/event/
# Out:
# event_play_2015_J1_10_s1.json  event_score_2015_J1_10_s1.json
# event_play_2015_J1_10_s2.json  event_score_2015_J1_10_s2.json
# event_play_2015_J1_11_s1.json  event_score_2015_J1_11_s1.json
# event_play_2015_J1_11_s2.json  event_score_2015_J1_11_s2.json
# event_play_2015_J1_12_s1.json  event_score_2015_J1_12_s1.json
# event_play_2015_J1_12_s2.json  event_score_2015_J1_12_s2.json
# event_play_2015_J1_18_s1.json  event_score_2015_J1_18_s1.json
# event_play_2015_J1_18_s2.json  event_score_2015_J1_18_s2.json
# event_play_2015_J1_1_s1.json   event_score_2015_J1_1_s1.json
# event_play_2015_J1_1_s2.json   event_score_2015_J1_1_s2.json
# event_play_2015_J1_21_s1.json  event_score_2015_J1_21_s1.json
# event_play_2015_J1_21_s2.json  event_score_2015_J1_21_s2.json
# event_play_2015_J1_22_s1.json  event_score_2015_J1_22_s1.json
# event_play_2015_J1_22_s2.json  event_score_2015_J1_22_s2.json
# event_play_2015_J1_28_s1.json  event_score_2015_J1_28_s1.json
# ...

# %%
files_play = sorted(glob(DATA_DIR+'event/*_play_*'))
files_score = sorted(glob(DATA_DIR+'event/*_score_*'))
files_we = sorted(glob(DATA_DIR+'event/*_we_*'))
files_rc = sorted(glob(DATA_DIR+'event/*_rc_*'))

# %%
num = 0
file = files_play[num]

# %%
df = pd.read_csv(file)
print(file)
print(df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-8-48944596a1d2> in <module>
# ----> 1 df = pd.read_csv(file)
#       2 print(file)
#       3 print(df.shape)
#       4 df.head()
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
# ...
